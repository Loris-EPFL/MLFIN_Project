# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_dataset(data):
    # Basic info
    print(f"Dataset shape: {data.shape}")
    
    # Calculate coverage statistics
    total_rows = len(data)
    
    # Create a dataframe to store column statistics
    stats = pd.DataFrame({
        'dtype': data.dtypes,
        'non_null_count': data.count(),
        'null_count': data.isnull().sum(),
        'null_percentage': (data.isnull().sum() / total_rows * 100).round(2),
        'coverage_percentage': ((total_rows - data.isnull().sum()) / total_rows * 100).round(2),
        'unique_values': data.nunique(),
        'unique_percentage': (data.nunique() / total_rows * 100).round(2)
    })
    
    # Add additional statistics for numeric columns
    numeric_cols = data.select_dtypes(include=['number']).columns
    for col in numeric_cols:
        stats.loc[col, 'min'] = data[col].min()
        stats.loc[col, 'max'] = data[col].max()
        stats.loc[col, 'mean'] = data[col].mean()
        stats.loc[col, 'std'] = data[col].std()
        stats.loc[col, 'zeros_percentage'] = (data[col] == 0).sum() / total_rows * 100
    
    # Sort by null percentage
    stats = stats.sort_values('null_percentage', ascending=False)
    
    return stats

def plot_coverage(stats):
    plt.figure(figsize=(12, 8))
    
    # Plot coverage percentage
    coverage_data = stats['coverage_percentage'].sort_values()
    plt.barh(coverage_data.index, coverage_data.values, color='skyblue')
    
    plt.xlabel('Coverage Percentage')
    plt.title('Column Coverage Percentage')
    plt.tight_layout()
    plt.show()
    
    # Plot null percentage for columns with missing values
    null_data = stats[stats['null_percentage'] > 0]['null_percentage'].sort_values(ascending=False)
    
    if len(null_data) > 0:
        plt.figure(figsize=(12, 8))
        plt.barh(null_data.index, null_data.values, color='salmon')
        plt.xlabel('Null Percentage')
        plt.title('Columns with Missing Values')
        plt.tight_layout()
        plt.show()

def identify_low_information_columns(stats, null_threshold=50, unique_threshold=1):
    """Identify columns that might have low information content"""
    
    # Columns with high null percentage
    high_null_cols = stats[stats['null_percentage'] > null_threshold].index.tolist()
    
    # Columns with very few unique values (relative to dataset size)
    low_unique_cols = stats[(stats['unique_percentage'] < unique_threshold) & 
                           (stats['unique_values'] < 5)].index.tolist()
    
    # Columns that are mostly zeros (for numeric columns)
    high_zero_cols = []
    if 'zeros_percentage' in stats.columns:
        high_zero_cols = stats[stats['zeros_percentage'] > 90].index.tolist()
    
    return {
        'high_null_columns': high_null_cols,
        'low_unique_columns': low_unique_cols,
        'high_zero_columns': high_zero_cols
    }

# Main function to run the analysis
def main():
    # Load your data
    # Assuming the data is in a CSV file - adjust the path as needed
    try:
        # Try to read the data from the provided sample
        data = pd.read_csv('datasets_tests/merged_data_strict_4.csv')  # Replace with your file path

        # Fill remaining NaNs
        # Fill NaNs using the intelligent method
        cleaned_data = fill_remaining_nans(
            data, 
            id_column='cusip',  # Adjust to your company identifier column
            date_column='datadate',  # Adjust to your date column
            method='intelligent'
        )
        
        # If you're working with the sample data provided in the question
        # You can use this instead:
        # sample_data = """58608,2250,45888410,IAL,3442,0,1983-09-30,0.104214,0.010158,..."""
        # data = pd.read_csv(StringIO(sample_data))
        
        # Run the analysis
        stats = analyze_dataset(cleaned_data)
        
        # Display the statistics
        print("\nColumn Statistics:")
        print(stats)
        
        # Plot the coverage
        plot_coverage(stats)
        
        # Identify low information columns
        low_info = identify_low_information_columns(stats)
        
        print("\nColumns with high null percentage (>50%):")
        print(low_info['high_null_columns'])
        
        print("\nColumns with low unique values:")
        print(low_info['low_unique_columns'])
        
        print("\nNumeric columns that are mostly zeros (>90%):")
        print(low_info['high_zero_columns'])
        
        # Suggest columns to remove
        print("\nSuggested columns to consider removing:")
        all_suggested = set(low_info['high_null_columns'] + 
                           low_info['low_unique_columns'] + 
                           low_info['high_zero_columns'])
        print(list(all_suggested))

       
        
        # Save the cleaned data
        cleaned_data.to_csv('merged_compustat_returns_cleaned_data.csv', index=False)
        print("\nCleaned data saved as 'cleaned_data.csv'")
        
    except Exception as e:
        print(f"Error: {e}")
        print("Please provide a valid data file path or adjust the code to match your data format.")


def fill_remaining_nans(data, id_column='cusip', date_column='MthCalDt', method='intelligent'):
    """
    Fill remaining NaN values in the dataset using ffill for all columns except identifiers.
    Then sort the final dataframe by date.
    """
    if data is None or len(data) == 0:
        raise ValueError("No data provided or empty dataframe")
    
    # Make a copy to avoid modifying the original dataframe
    df = data.copy()
    
    # Ensure date column is in datetime format
    if pd.api.types.is_string_dtype(df[date_column]):
        df[date_column] = pd.to_datetime(df[date_column])
    
    # Define identifier columns that should not be filled
    identifier_columns = [
        'cusip', 'gvkey', 'iid', 'datadate', 'tic', 'conm', 'permno', 
        'permco', 'sic', 'naics', 'gics', 'ff49', 'exchg', 'exchcd', 
        'siccd', 'ticker', 'symbol'
    ]
    
    # Keep only the identifier columns that exist in our dataframe
    identifier_columns = [col for col in identifier_columns if col in df.columns]
    
    # Get all non-identifier columns that need to be filled
    columns_to_fill = [col for col in df.columns if col not in identifier_columns]
    
    # Store original NaN counts for reporting
    original_nan_counts = df.isna().sum()
    total_nans_before = original_nan_counts.sum()
    
    print(f"Filling remaining NaN values using forward fill method...")
    print(f"Total NaNs before: {total_nans_before:,}")
    
    # Process each company separately
    company_groups = []
    company_count = df[id_column].nunique()
    print(f"Processing {company_count} companies...")
    
    # Track progress
    processed = 0
    
    # Group by company ID and apply ffill
    for company_id, company_data in df.groupby(id_column):
        # Sort by date within each company group
        company_data = company_data.sort_values(date_column)
        
        # Forward fill all non-identifier columns
        for col in columns_to_fill:
            company_data[col] = company_data[col].fillna(method='ffill')
            # If any NaNs remain at the start of the series, backward fill them
            company_data[col] = company_data[col].fillna(method='bfill')
            # If any NaNs still remain, fill with 0 (for numeric columns only)
            if pd.api.types.is_numeric_dtype(company_data[col]):
                company_data[col] = company_data[col].fillna(0)
        
        # Add the processed company data to our list
        company_groups.append(company_data)
        
        # Update progress
        processed += 1
        if processed % 100 == 0:
            print(f"Processed {processed}/{company_count} companies ({processed/company_count*100:.1f}%)")
    
    # Combine all company data
    df = pd.concat(company_groups, ignore_index=True)
    
    # Report results
    final_nan_counts = df.isna().sum()
    total_nans_after = final_nan_counts.sum()
    
    print(f"Total NaNs after: {total_nans_after:,}")
    print(f"Filled {total_nans_before - total_nans_after:,} NaN values")
    
    # Report columns that still have NaNs
    cols_with_nans = final_nan_counts[final_nan_counts > 0]
    if not cols_with_nans.empty:
        print("\nColumns still containing NaNs:")
        for col, count in cols_with_nans.items():
            print(f"- {col}: {count:,} NaNs ({count/len(df)*100:.2f}%)")
    else:
        print("\nAll NaN values have been filled!")
    
    # Sort the final dataframe by date (oldest first, newest last)
    df = df.sort_values(by=date_column)
    
    return df
# Out:
# Filling remaining NaN values using forward fill method...
# Total NaNs before: 317,532
# Processing 8122 companies...
# /tmp/ipykernel_1402/3292659662.py:194: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   company_data[col] = company_data[col].fillna(method='ffill')
# /tmp/ipykernel_1402/3292659662.py:196: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   company_data[col] = company_data[col].fillna(method='bfill')
# Processed 100/8122 companies (1.2%)
# Processed 200/8122 companies (2.5%)
# Processed 300/8122 companies (3.7%)
# Processed 400/8122 companies (4.9%)
# Processed 500/8122 companies (6.2%)
# Processed 600/8122 companies (7.4%)
# Processed 700/8122 companies (8.6%)
# Processed 800/8122 companies (9.8%)
# Processed 900/8122 companies (11.1%)
# Processed 1000/8122 companies (12.3%)
# Processed 1100/8122 companies (13.5%)
# Processed 1200/8122 companies (14.8%)
# Processed 1300/8122 companies (16.0%)
# Processed 1400/8122 companies (17.2%)
# Processed 1500/8122 companies (18.5%)
# Processed 1600/8122 companies (19.7%)
# /tmp/ipykernel_1402/3292659662.py:194: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   company_data[col] = company_data[col].fillna(method='ffill')
# Processed 1700/8122 companies (20.9%)
# Processed 1800/8122 companies (22.2%)
# Processed 1900/8122 companies (23.4%)
# Processed 2000/8122 companies (24.6%)
# Processed 2100/8122 companies (25.9%)
# Processed 2200/8122 companies (27.1%)
# Processed 2300/8122 companies (28.3%)
# Processed 2400/8122 companies (29.5%)
# Processed 2500/8122 companies (30.8%)
# Processed 2600/8122 companies (32.0%)
# Processed 2700/8122 companies (33.2%)
# Processed 2800/8122 companies (34.5%)
# Processed 2900/8122 companies (35.7%)
# Processed 3000/8122 companies (36.9%)
# Processed 3100/8122 companies (38.2%)
# Processed 3200/8122 companies (39.4%)
# Processed 3300/8122 companies (40.6%)
# Processed 3400/8122 companies (41.9%)
# Processed 3500/8122 companies (43.1%)
# Processed 3600/8122 companies (44.3%)
# Processed 3700/8122 companies (45.6%)
# Processed 3800/8122 companies (46.8%)
# Processed 3900/8122 companies (48.0%)
# Processed 4000/8122 companies (49.2%)
# Processed 4100/8122 companies (50.5%)
# Processed 4200/8122 companies (51.7%)
# Processed 4300/8122 companies (52.9%)
# Processed 4400/8122 companies (54.2%)
# Processed 4500/8122 companies (55.4%)
# Processed 4600/8122 companies (56.6%)
# Processed 4700/8122 companies (57.9%)
# Processed 4800/8122 companies (59.1%)
# Processed 4900/8122 companies (60.3%)
# Processed 5000/8122 companies (61.6%)
# Processed 5100/8122 companies (62.8%)
# Processed 5200/8122 companies (64.0%)
# Processed 5300/8122 companies (65.3%)
# Processed 5400/8122 companies (66.5%)
# Processed 5500/8122 companies (67.7%)
# Processed 5600/8122 companies (68.9%)
# Processed 5700/8122 companies (70.2%)
# Processed 5800/8122 companies (71.4%)
# Processed 5900/8122 companies (72.6%)
# Processed 6000/8122 companies (73.9%)
# Processed 6100/8122 companies (75.1%)
# Processed 6200/8122 companies (76.3%)
# Processed 6300/8122 companies (77.6%)
# Processed 6400/8122 companies (78.8%)
# Processed 6500/8122 companies (80.0%)
# Processed 6600/8122 companies (81.3%)
# Processed 6700/8122 companies (82.5%)
# Processed 6800/8122 companies (83.7%)
# Processed 6900/8122 companies (85.0%)
# Processed 7000/8122 companies (86.2%)
# Processed 7100/8122 companies (87.4%)
# Processed 7200/8122 companies (88.6%)
# Processed 7300/8122 companies (89.9%)
# Processed 7400/8122 companies (91.1%)
# Processed 7500/8122 companies (92.3%)
# Processed 7600/8122 companies (93.6%)
# Processed 7700/8122 companies (94.8%)
# Processed 7800/8122 companies (96.0%)
# Processed 7900/8122 companies (97.3%)
# Processed 8000/8122 companies (98.5%)
# Processed 8100/8122 companies (99.7%)
# Total NaNs after: 0
# Filled 317,532 NaN values
#
# All NaN values have been filled!
# Dataset shape: (493737, 51)
#
# Column Statistics:
#                                dtype  non_null_count  null_count  \
# PERMNO                         int64          493737           0
# PERMCO                         int64          493737           0
# cusip                         object          493737           0
# Ticker                        object          493737           0
# SICCD                          int64          493737           0
# NAICS                          int64          493737           0
# MthCalDt                      object          493737           0
# MthRet                       float64          493737           0
# sprtrn                       float64          493737           0
# datadate              datetime64[ns]          493737           0
# tic                           object          493737           0
# exchg                        float64          493737           0
# gvkey                        float64          493737           0
# conm                          object          493737           0
# cik                          float64          493737           0
# epspxy                       float64          493737           0
# epspiy                       float64          493737           0
# epsfiy                       float64          493737           0
# epsfxy                       float64          493737           0
# oiadpy                       float64          493737           0
# cshpry                       float64          493737           0
# dvy                          float64          493737           0
# capxy                        float64          493737           0
# sstky                        float64          493737           0
# aqcy                         float64          493737           0
# prstkcy                      float64          493737           0
# dltry                        float64          493737           0
# dltisy                       float64          493737           0
# sivy                         float64          493737           0
# ivchy                        float64          493737           0
# ibcy                         float64          493737           0
# fopoy                        float64          493737           0
# dpcy                         float64          493737           0
# niy                          float64          493737           0
# saley                        float64          493737           0
# iby                          float64          493737           0
# revty                        float64          493737           0
# txty                         float64          493737           0
# piy                          float64          493737           0
# txdcy                        float64          493737           0
# nopiy                        float64          493737           0
# xopry                        float64          493737           0
# cogsy                        float64          493737           0
# chechy                       float64          493737           0
# earnings_growth              float64          493737           0
# revenue_growth               float64          493737           0
# net_debt_change              float64          493737           0
# capex_growth                 float64          493737           0
# eps_surprise                 float64          493737           0
# dividend_change              float64          493737           0
# repurchase_intensity         float64          493737           0
#
#                       null_percentage  coverage_percentage  unique_values  \
# PERMNO                            0.0                100.0           8089
# PERMCO                            0.0                100.0           8083
# cusip                             0.0                100.0           8122
# Ticker                            0.0                100.0           8083
# SICCD                             0.0                100.0           1158
# NAICS                             0.0                100.0            961
# MthCalDt                          0.0                100.0            439
# MthRet                            0.0                100.0         222102
# sprtrn                            0.0                100.0            439
# datadate                          0.0                100.0            439
# tic                               0.0                100.0           8122
# exchg                             0.0                100.0             14
# gvkey                             0.0                100.0           8122
# conm                              0.0                100.0           8121
# cik                               0.0                100.0           7868
# epspxy                            0.0                100.0           3718
# epspiy                            0.0                100.0           3871
# epsfiy                            0.0                100.0           3837
# epsfxy                            0.0                100.0           3696
# oiadpy                            0.0                100.0         125217
# cshpry                            0.0                100.0         103643
# dvy                               0.0                100.0          66208
# capxy                             0.0                100.0          73045
# sstky                             0.0                100.0          36978
# aqcy                              0.0                100.0          31140
# prstkcy                           0.0                100.0          41630
# dltry                             0.0                100.0          79154
# dltisy                            0.0                100.0          63511
# sivy                              0.0                100.0          62029
# ivchy                             0.0                100.0          71614
# ibcy                              0.0                100.0         108271
# fopoy                             0.0                100.0          66521
# dpcy                              0.0                100.0          75993
# niy                               0.0                100.0         106523
# saley                             0.0                100.0         172853
# iby                               0.0                100.0         105539
# revty                             0.0                100.0         155684
# txty                              0.0                100.0          67704
# piy                               0.0                100.0         116033
# txdcy                             0.0                100.0          38967
# nopiy                             0.0                100.0          55125
# xopry                             0.0                100.0         160519
# cogsy                             0.0                100.0         150994
# chechy                            0.0                100.0         101791
# earnings_growth                   0.0                100.0         201086
# revenue_growth                    0.0                100.0         204679
# net_debt_change                   0.0                100.0         107062
# capex_growth                      0.0                100.0         189821
# eps_surprise                      0.0                100.0           6291
# dividend_change                   0.0                100.0         175253
# repurchase_intensity              0.0                100.0         118631
#
#                       unique_percentage            min           max  \
# PERMNO                             1.64   10001.000000  9.342900e+04
# PERMCO                             1.64       4.000000  6.005800e+04
# cusip                              1.65            NaN           NaN
# Ticker                             1.64            NaN           NaN
# SICCD                              0.23       0.000000  9.999000e+03
# NAICS                              0.19       0.000000  9.281100e+05
# MthCalDt                           0.09            NaN           NaN
# MthRet                            44.98      -1.000000  8.995002e+00
# sprtrn                             0.09      -0.169425  1.630470e-01
# datadate                           0.09            NaN           NaN
# tic                                1.65            NaN           NaN
# exchg                              0.00       0.000000  2.100000e+01
# gvkey                              1.65    1004.000000  3.561280e+05
# conm                               1.64            NaN           NaN
# cik                                1.59       0.000000  2.042694e+06
# epspxy                             0.75  -19436.150000  7.851400e+02
# epspiy                             0.78  -19436.150000  7.851400e+02
# epsfiy                             0.78  -19436.150000  7.845100e+02
# epsfxy                             0.75  -19436.150000  7.845100e+02
# oiadpy                            25.36  -45026.000000  1.232160e+05
# cshpry                            20.99       0.001100  2.459900e+04
# dvy                               13.41     -14.958000  3.770100e+04
# capxy                             14.79    -994.000000  4.511000e+04
# sstky                              7.49    -713.362000  6.271200e+04
# aqcy                               6.31 -108510.000000  6.661100e+04
# prstkcy                            8.43     -39.880000  1.003900e+05
# dltry                             16.03     -47.781000  6.007355e+06
# dltisy                            12.86    -241.002000  6.019062e+06
# sivy                              12.56    -375.602000  2.293149e+06
# ivchy                             14.50     -55.000000  2.380332e+06
# ibcy                              21.93  -72022.000000  9.980300e+04
# fopoy                             13.47  -97965.625000  5.172000e+04
# dpcy                              15.39     -23.618000  4.466700e+04
# niy                               21.57  -71969.000000  9.980300e+04
# saley                             35.01  -59743.000000  6.481250e+05
# iby                               21.38  -71969.000000  9.980300e+04
# revty                             31.53  -59743.000000  6.481250e+05
# txty                              13.71  -34831.000000  4.986000e+04
# piy                               23.50  -73007.000000  1.234850e+05
# txdcy                              7.89  -34235.000000  2.487700e+04
# nopiy                             11.16  -38289.329000  2.267200e+04
# xopry                             32.51  -56630.000000  6.091670e+05
# cogsy                             30.58  -59351.000000  4.782890e+05
# chechy                            20.62 -189891.000000  2.639780e+05
# earnings_growth                   40.73  -10014.320000  1.130600e+04
# revenue_growth                    41.46     -96.525346  1.000100e+04
# net_debt_change                   21.68 -163475.000000  1.289370e+05
# capex_growth                      38.45     -49.500000  1.819460e+05
# eps_surprise                       1.27   -8075.410000  1.942195e+04
# dividend_change                   35.50    -115.000000  2.610850e+05
# repurchase_intensity              24.03    -119.286408  1.376125e+03
#
#                                mean            std  zeros_percentage
# PERMNO                 58625.978924   28246.668828          0.000000
# PERMCO                 23091.186253   16635.153320          0.000000
# cusip                           NaN            NaN               NaN
# Ticker                          NaN            NaN               NaN
# SICCD                   4878.984834    2051.267698          0.163042
# NAICS                 264730.106942  234621.310827         39.506458
# MthCalDt                        NaN            NaN               NaN
# MthRet                     0.010699       0.120892          1.457456
# sprtrn                     0.008582       0.043639          0.000000
# datadate                        NaN            NaN               NaN
# tic                             NaN            NaN               NaN
# exchg                     12.618054       2.417776          0.001418
# gvkey                  42592.478447   58816.372843          0.000000
# conm                            NaN            NaN               NaN
# cik                   694511.999644  517398.189391          1.484191
# epspxy                     1.197198      28.153845          0.368010
# epspiy                     1.218904      28.195685          0.346541
# epsfiy                     1.203517      28.191104          0.373073
# epsfxy                     1.181367      28.149459          0.392112
# oiadpy                   570.817769    2589.330593          0.005063
# cshpry                   194.762557     686.841270          0.000000
# dvy                      152.274358     662.428527          6.541337
# capxy                    248.188741    1172.896135         11.126977
# sstky                     56.667573     576.503221         35.745144
# aqcy                      78.280374     924.938794         71.718344
# prstkcy                  141.735285    1075.426132         47.819588
# dltry                    843.824359   27916.379352         21.295751
# dltisy                   954.442412   28023.767552         39.449748
# sivy                    1209.393432   20982.462419         57.108137
# ivchy                   1494.132384   22857.658249         52.923520
# ibcy                     313.717236    1634.962388          2.743363
# fopoy                     78.072659     963.617704         13.165106
# dpcy                     214.336811     954.107317          5.760354
# niy                      310.925171    1675.584753          0.013570
# saley                   3684.001413   15072.432002          0.000000
# iby                      306.319202    1625.032948          0.014178
# revty                   3504.167845   14784.107802         10.576684
# txty                     117.748129     689.192908          9.074062
# piy                      434.005324    2212.423932          0.350186
# txdcy                     -0.478046     284.938336         34.159887
# nopiy                     -1.037041     741.240440         15.491446
# xopry                   2926.761575   12846.996693          2.876430
# cogsy                   2418.230415   11224.956414          3.067220
# chechy                    49.830693    2925.672240          0.851871
# earnings_growth            0.501558      57.690664          0.143599
# revenue_growth             0.353490      25.085066          0.119699
# net_debt_change          107.294262    1835.431855         18.509652
# capex_growth               2.279662     387.715769          8.774510
# eps_surprise               0.138206      49.437442          1.433962
# dividend_change            5.922671     719.721395          4.853799
# repurchase_intensity       0.045704       2.796893         47.819588
# Columns with high null percentage (>50%):
# []
#
# Columns with low unique values:
# []
#
# Numeric columns that are mostly zeros (>90%):
# []
#
# Suggested columns to consider removing:
# []
#
# Cleaned data saved as 'cleaned_data.csv'

# %%
# Run the above code to clean the data
main()

# %%
# Transform csv into parquet for easier storage

import pandas as pd
df = pd.read_csv("datasets/PostProcessed/Merged/merged_compustat_returns_cleaned_data.csv")
df.to_parquet(
    "datasets/PostProcessed/Merged/merged_compustat_returns_cleaned_data.parquet",
    engine="pyarrow",
)
