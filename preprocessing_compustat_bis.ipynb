# %% [markdown]
# Code to preprocess the Compustat data, used with collab here because dataset was too large to be computed locally. Either use collab or have a PC with enough RAM to run the code.

# %%
# RUn with Collab
from google.colab import drive
import os
import pandas as pd
drive.mount('/content/gdrive',force_remount=True)
folder = '/content/gdrive/My Drive/datasets_mlfin'

# %%
# RUn with ram
folder = '/datasets/Predictors'

# %%
# process_compustat.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import seaborn as sns
from preprocessing.preprocessing_compustat_bis import CompustatPreprocessor

# Initialize the preprocessor
preprocessor1 = CompustatPreprocessor(date_column='datadate', id_column='cusip')

# Step 1: Load the data
preprocessor1.load((os.path.join(folder, 'CompFirmCharac.csv')))

# Step 2: Explore the data to understand its structure
preprocessor1.explore_data()

# Step 3: Visualize missing values
preprocessor1.plot_missing_values(top_n=100)

# Step 4: Convert dates to proper format
preprocessor1.convert_dates()

cusips = pd.read_csv((os.path.join(folder, 'cusip_list.csv')))

preprocessor1.filter_by_returns_cusips(cusips)

# Step 5: Check column coverage and save to file
coverage = preprocessor1.check_column_coverage()
print(coverage)

# Step 6: Get recommended columns with good coverage
recommended_columns = preprocessor1.recommend_columns_for_sentiment(min_coverage=30)
print("Recommended columns:", recommended_columns)

# Step 7: Select important financial columns
preprocessor1.select_important_columns()


# Step 9: Sort data by date
preprocessor1.global_sort_by_date()

# Step 10: Fix data types
preprocessor1.fix_data_types()

# Step 11: Handle duplicates
preprocessor1.handle_duplicates()

# Step 12: Clean string 'nan' values
preprocessor1.clean_string_nan_values()

# Step 13: Replace remaining NaNs in string columns with empty strings
preprocessor1.handle_missing_values(method='empty_strings')

# Step 14: Filter columns by coverage (keep only columns with at least 30% coverage)
preprocessor1.filter_columns_by_coverage(min_coverage=30)

# Step 15: Get the processed quarterly data before interpolation
quarterly_data = preprocessor1.get_data()
print("\n=== Quarterly Data Summary (Before Interpolation) ===")
print(f"Shape: {quarterly_data.shape}")
print("\nSample of quarterly data:")
print(quarterly_data.head())


# Step 17: Interpolate quarterly data to monthly frequency
print("\n=== Starting Quarterly to Monthly Interpolation ===")
preprocessor1.interpolate_quarterly_to_monthly(min_coverage=30)

# Step 8: Create financial indicators for sentiment analysis
preprocessor1.create_sentiment_indicators()

# Step 19: Get the processed monthly data after interpolation
monthly_data = preprocessor1.get_data()
print("\n=== Monthly Data Summary (After Interpolation) ===")
print(f"Shape: {monthly_data.shape}")
print("\nSample of monthly data:")
print(monthly_data.head())

# Step 20: Plot examples of interpolation for visual inspection
print("\n=== Plotting Interpolation Examples ===")
# Try to find good columns for visualization
good_columns = ['epspxy', 'oiadpy', 'saley', 'earnings_growth', 'revenue_growth']
for col in good_columns:
    if col in monthly_data.columns:
        print(f"Plotting interpolation example for {col}")
        preprocessor1.plot_interpolation_example(column=col, n_samples=2)
        break

# Step 21: Export the processed monthly data
preprocessor1.export_data((os.path.join(folder, 'processed_data_compustat.csv')), format='csv')
# Out:
# Loading data from datasets/Predictors/CompFirmCharac.csv
# Loading 100000 rows
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:135: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(
# Loaded dataset with shape: (100000, 256)
# Converted datadate to datetime
#
# === Dataset Overview ===
# Shape: (100000, 256)
#
# === Data Types ===
#        Column            Type
# 0       gvkey           int64
# 1    datadate  datetime64[ns]
# 2      fyearq           int64
# 3        fqtr         float64
# 4         fyr           int64
# ..        ...             ...
# 251     xsgay         float64
# 252     exchg           int64
# 253       cik         float64
# 254    costat          object
# 255       fic          object
#
# [256 rows x 2 columns]
#
# === Missing Values ===
#        Column  Missing Values  Percentage
# 75   finxopry          100000     100.000
# 206    tsafcy          100000     100.000
# 218  ufretsdy          100000     100.000
# 222    unwccy          100000     100.000
# 232  uwkcapcy          100000     100.000
# ..        ...             ...         ...
# 43     cshpry           15985      15.985
# 253       cik           11389      11.389
# 13   datacqtr             162       0.162
# 14   datafqtr              14       0.014
# 3        fqtr               3       0.003
#
# [241 rows x 3 columns]
# Total columns with missing values: 241
#
# === Categorical Columns ===
# indfmt: 1 unique values
# Values: ['INDL']
# consol: 1 unique values
# Values: ['C']
# popsrc: 1 unique values
# Values: ['D']
# datafmt: 1 unique values
# Values: ['STD']
# tic: 1311 unique values
# cusip: 1323 unique values
# conm: 1311 unique values
# curcdq: 2 unique values
# Values: ['CAD', 'USD']
# datacqtr: 256 unique values
# datafqtr: 259 unique values
# costat: 2 unique values
# Values: ['A', 'I']
# fic: 10 unique values
#
# === Time Range ===
# From 1961-05-31 00:00:00 to 2025-03-31 00:00:00
#
# === Company Count ===
# Dataset contains 1323 unique companies
# === Column Coverage ===
#        Column  Coverage (%)  Missing (%)       Data Type
# 0       gvkey         100.0          0.0           int64
# 1    datadate         100.0          0.0  datetime64[ns]
# 2      fyearq         100.0          0.0           int64
# 4         fyr         100.0          0.0           int64
# 6      consol         100.0          0.0          object
# ..        ...           ...          ...             ...
# 218  ufretsdy           0.0        100.0         float64
# 232  uwkcapcy           0.0        100.0         float64
# 227   ustdncy           0.0        100.0         float64
# 229   utfdocy           0.0        100.0         float64
# 230   utfoscy           0.0        100.0         float64
#
# [256 rows x 4 columns]
#
# === Column Coverage ===
#        Column  Coverage (%)  Missing (%)       Data Type
# 0       gvkey         100.0          0.0           int64
# 1    datadate         100.0          0.0  datetime64[ns]
# 2      fyearq         100.0          0.0           int64
# 4         fyr         100.0          0.0           int64
# 6      consol         100.0          0.0          object
# ..        ...           ...          ...             ...
# 218  ufretsdy           0.0        100.0         float64
# 232  uwkcapcy           0.0        100.0         float64
# 227   ustdncy           0.0        100.0         float64
# 229   utfdocy           0.0        100.0         float64
# 230   utfoscy           0.0        100.0         float64
#
# [256 rows x 4 columns]
#
# === Recommended Columns for Sentiment Analysis (35) ===
# Essential: datadate, gvkey, cusip, tic, conm, exchg, cik
# Earnings: epspxy, epspiy, epsfxy, epsfiy, niy, iby, ibcy, oiadpy
# Revenue: saley, revty
# Expenses: cogsy, xopry, xsgay, dpcy
# Cash Flow: capxy, dvy, oancfy, fincfy, ivncfy
# Debt: dltisy, dltry, dlcchy
# Assets: chechy, ivchy, sivy, aqcy
# Equity: sstky, prstkcy
# Recommended columns: ['datadate', 'gvkey', 'cusip', 'tic', 'conm', 'exchg', 'cik', 'epspxy', 'epspiy', 'epsfxy', 'epsfiy', 'niy', 'iby', 'ibcy', 'oiadpy', 'saley', 'revty', 'cogsy', 'xopry', 'xsgay', 'dpcy', 'capxy', 'dvy', 'oancfy', 'fincfy', 'ivncfy', 'dltisy', 'dltry', 'dlcchy', 'chechy', 'ivchy', 'sivy', 'aqcy', 'sstky', 'prstkcy']
# Selected 36 important columns out of 256
# First few columns: datadate, gvkey, cusip, tic, conm
#
# === Selected Column Categories ===
# Identifiers: datadate, gvkey, cusip, tic, conm, exchg, cik
# Performance Metrics: epspxy, epspiy, epsfiy, epsfxy, oiadpy, cshpry
# Additional Financial Metrics: dvy, capxy, sstky, aqcy, prstkcy, dltry, dltisy, sivy, ivchy, chechy, ibcy, fopoy, dpcy
# Income Statement Items: niy, saley, iby, revty, txty, piy, txdcy, nopiy, xopry, cogsy
# Creating financial indicators for sentiment analysis...
# Created Earnings Growth indicator
# Created Revenue Growth indicator
# Created Net Debt Change indicator
# Created Capital Expenditure Growth indicator
# Created EPS Surprise indicator
# Created Dividend Change indicator
# Created Stock Repurchase Intensity indicator
# Removed 5 temporary calculation columns
# Data sorted globally by datadate from oldest to newest
# Fixing data types...
# Converted gvkey to string
# Converted cusip to string
# Converted cik to string
# Converted exchg to string
# Found 150 duplicate rows based on cusip and datadate
# Removed 150 duplicate rows
# Replaced 11383 string 'nan' values with empty strings in column 'cik'
# Total string 'nan' values replaced: 11383
# Handling missing values using empty_strings method...
# Missing values: 1598255 out of 4296775 cells (37.20%)
# Replaced NaN values with empty strings in column 'gvkey'
# Replaced NaN values with empty strings in column 'cusip'
# Replaced NaN values with empty strings in column 'tic'
# Replaced NaN values with empty strings in column 'conm'
# Replaced NaN values with empty strings in column 'exchg'
# Replaced NaN values with empty strings in column 'cik'
# Warning: 1598255 missing values remain after processing
# Filtering columns with coverage < 30%...
#
# === Column Coverage ===
#                   Column  Coverage (%)  Missing (%)       Data Type
# 0               datadate    100.000000     0.000000  datetime64[ns]
# 1                  gvkey    100.000000     0.000000          object
# 2                  cusip    100.000000     0.000000          object
# 3                    tic    100.000000     0.000000          object
# 4                   conm    100.000000     0.000000          object
# 5                  exchg    100.000000     0.000000          object
# 6                    cik    100.000000     0.000000          object
# 12                cshpry     84.015011    15.984989         float64
# 7                 epspxy     82.505879    17.494121         float64
# 8                 epspiy     82.412810    17.587190         float64
# 9                 epsfiy     79.245434    20.754566         float64
# 10                epsfxy     79.137353    20.862647         float64
# 40          eps_surprise     77.409057    22.590943         float64
# 11                oiadpy     76.174131    23.825869         float64
# 13                   dvy     57.143858    42.856142         float64
# 14                 capxy     56.585439    43.414561         float64
# 15                 sstky     55.939955    44.060045         float64
# 17               prstkcy     55.874906    44.125094         float64
# 16                  aqcy     55.763823    44.236177         float64
# 18                 dltry     55.299475    44.700525         float64
# 19                dltisy     55.165374    44.834626         float64
# 21                 ivchy     54.807105    45.192895         float64
# 20                  sivy     54.603953    45.396047         float64
# 22                chechy     53.911434    46.088566         float64
# 38       net_debt_change     53.309982    46.690018         float64
# 23                  ibcy     53.119840    46.880160         float64
# 24                 fopoy     53.100826    46.899174         float64
# 25                  dpcy     51.315487    48.684513         float64
# 28                   iby     49.023768    50.976232         float64
# 26                   niy     48.949712    51.050288         float64
# 27                 saley     48.856642    51.143358         float64
# 30                  txty     48.355266    51.644734         float64
# 32                 txdcy     48.324243    51.675757         float64
# 31                   piy     48.267200    51.732800         float64
# 39          capex_growth     48.158119    51.841881         float64
# 29                 revty     47.511634    52.488366         float64
# 33                 nopiy     45.846385    54.153615         float64
# 35                 cogsy     45.135852    54.864148         float64
# 34                 xopry     45.027771    54.972229         float64
# 36       earnings_growth     44.659495    55.340505         float64
# 37        revenue_growth     43.668752    56.331248         float64
# 42  repurchase_intensity     35.909932    64.090068         float64
# 41       dividend_change     26.009507    73.990493         float64
# Removing 1 columns with poor coverage (<30%):
# dividend_change
# Remaining columns: 42
#
# === Quarterly Data Summary (Before Interpolation) ===
# Shape: (99925, 42)
#
# Sample of quarterly data:
#         datadate gvkey      cusip    tic                      conm exchg  \
# 68386 1961-05-31  2102  074077934  4708C          BEATRICE COS INC     3
# 33763 1961-06-30  1572  030095103  ASE.2  AMERICAN STORES CO  -OLD    11
# 19226 1961-07-31  1319  020051108  ALYN.         ALLYN & BACON INC    13
# 20518 1961-07-31  1345  021447107  3ALRM  ALTERMAN INVESTMENT FUND    13
# 79626 1961-07-31  2283  096779202   BBKS         BOBBIE BROOKS INC    13
#
#             cik  epspxy  epspiy  epsfiy  ...  txdcy  nopiy  xopry  cogsy  \
# 68386  785960.0    0.56    0.56     NaN  ...    NaN    NaN    NaN    NaN
# 33763              1.37    1.37     NaN  ...    NaN    NaN    NaN    NaN
# 19226    4047.0     NaN     NaN     NaN  ...    NaN    NaN    NaN    NaN
# 20518  315127.0    0.31    0.31     NaN  ...    NaN    NaN    NaN    NaN
# 79626   14537.0    0.54     NaN     NaN  ...    NaN    NaN    NaN    NaN
#
#        earnings_growth  revenue_growth  net_debt_change  capex_growth  \
# 68386              NaN             NaN              NaN           NaN
# 33763              NaN             NaN              NaN           NaN
# 19226              NaN             NaN              NaN           NaN
# 20518              NaN             NaN              NaN           NaN
# 79626              NaN             NaN              NaN           NaN
#
#        eps_surprise  repurchase_intensity
# 68386           NaN                   NaN
# 33763           NaN                   NaN
# 19226           NaN                   NaN
# 20518           NaN                   NaN
# 79626           NaN                   NaN
#
# [5 rows x 42 columns]
# Data exported to datasets/PostProcessed/Predictors/compustat_quarterly_processed.csv
# Shape: (99925, 42)
#
# === Starting Quarterly to Monthly Interpolation ===
# Interpolating quarterly data to monthly frequency using cubic method...
#
# === Column Coverage ===
#                   Column  Coverage (%)  Missing (%)       Data Type
# 0               datadate    100.000000     0.000000  datetime64[ns]
# 1                  gvkey    100.000000     0.000000          object
# 2                  cusip    100.000000     0.000000          object
# 3                    tic    100.000000     0.000000          object
# 4                   conm    100.000000     0.000000          object
# 5                  exchg    100.000000     0.000000          object
# 6                    cik    100.000000     0.000000          object
# 12                cshpry     84.015011    15.984989         float64
# 7                 epspxy     82.505879    17.494121         float64
# 8                 epspiy     82.412810    17.587190         float64
# 9                 epsfiy     79.245434    20.754566         float64
# 10                epsfxy     79.137353    20.862647         float64
# 40          eps_surprise     77.409057    22.590943         float64
# 11                oiadpy     76.174131    23.825869         float64
# 13                   dvy     57.143858    42.856142         float64
# 14                 capxy     56.585439    43.414561         float64
# 15                 sstky     55.939955    44.060045         float64
# 17               prstkcy     55.874906    44.125094         float64
# 16                  aqcy     55.763823    44.236177         float64
# 18                 dltry     55.299475    44.700525         float64
# 19                dltisy     55.165374    44.834626         float64
# 21                 ivchy     54.807105    45.192895         float64
# 20                  sivy     54.603953    45.396047         float64
# 22                chechy     53.911434    46.088566         float64
# 38       net_debt_change     53.309982    46.690018         float64
# 23                  ibcy     53.119840    46.880160         float64
# 24                 fopoy     53.100826    46.899174         float64
# 25                  dpcy     51.315487    48.684513         float64
# 28                   iby     49.023768    50.976232         float64
# 26                   niy     48.949712    51.050288         float64
# 27                 saley     48.856642    51.143358         float64
# 30                  txty     48.355266    51.644734         float64
# 32                 txdcy     48.324243    51.675757         float64
# 31                   piy     48.267200    51.732800         float64
# 39          capex_growth     48.158119    51.841881         float64
# 29                 revty     47.511634    52.488366         float64
# 33                 nopiy     45.846385    54.153615         float64
# 35                 cogsy     45.135852    54.864148         float64
# 34                 xopry     45.027771    54.972229         float64
# 36       earnings_growth     44.659495    55.340505         float64
# 37        revenue_growth     43.668752    56.331248         float64
# 41  repurchase_intensity     35.909932    64.090068         float64
# Found 35 numeric columns with ≥30% coverage to interpolate
# Keeping 7 essential/non-numeric columns without interpolation
# Processing 1322 companies...
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# Error interpolating eps_surprise for company 001320100: The number of derivatives at boundaries does not match: expected 1, got 0+0
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# Processed 100/1322 companies (7.6%)
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# ...
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# Processed 1300/1322 companies (98.3%)
# Error interpolating oiadpy for company 9292103: The number of derivatives at boundaries does not match: expected 1, got 0+0
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# /home/Loris/EPFL/MA2/MLFIN/Project/preprocessing/preprocessing_compustat_bis.py:1121: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_dates = pd.date_range(start=start_date, end=end_date, freq='M')
# Interpolation complete. Created monthly data with shape: (297614, 77)
# Adding 4-month reporting delay...
# Created 'available_date' column: datadate + 4 months
#
# === Monthly Data Summary (After Interpolation) ===
# Shape: (297614, 78)
#
# Sample of monthly data:
#     datadate      cusip gvkey exchg                   conm cik   tic  epspxy  \
# 0 1966-03-31  000032102  1000    12  A & E PLASTIK PAK INC      AE.2     NaN
# 1 1966-04-30  000032102  1000    12  A & E PLASTIK PAK INC      AE.2     NaN
# 2 1966-05-31  000032102  1000    12  A & E PLASTIK PAK INC      AE.2     NaN
# 3 1966-06-30  000032102  1000    12  A & E PLASTIK PAK INC      AE.2     NaN
# 4 1966-07-31  000032102  1000    12  A & E PLASTIK PAK INC      AE.2     NaN
#
#    epspxy_mom_change  epspiy  ...  cogsy_mom_change  earnings_growth  \
# 0                NaN     NaN  ...               NaN              NaN
# 1                NaN     NaN  ...               NaN              NaN
# 2                NaN     NaN  ...               NaN              NaN
# 3                NaN     NaN  ...               NaN              NaN
# 4                NaN     NaN  ...               NaN              NaN
#
#    earnings_growth_mom_change  revenue_growth  revenue_growth_mom_change  \
# 0                         NaN             NaN                        NaN
# 1                         NaN             NaN                        NaN
# 2                         NaN             NaN                        NaN
# 3                         NaN             NaN                        NaN
# 4                         NaN             NaN                        NaN
#
#    capex_growth  capex_growth_mom_change  repurchase_intensity  \
# 0           NaN                      NaN                   NaN
# 1           NaN                      NaN                   NaN
# 2           NaN                      NaN                   NaN
# 3           NaN                      NaN                   NaN
# 4           NaN                      NaN                   NaN
#
#    repurchase_intensity_mom_change  available_date
# 0                              NaN      1966-07-31
# 1                              NaN      1966-08-30
# 2                              NaN      1966-09-30
# 3                              NaN      1966-10-30
# 4                              NaN      1966-11-30
#
# [5 rows x 78 columns]
#
# === Plotting Interpolation Examples ===
# Plotting interpolation example for epspxy
# Data exported to datasets/PostProcessed/Predictors/compustat_monthly_interpolated.csv
# Shape: (297614, 78)
#
# === Analyzing Interpolation Quality ===
# Analyzing interpolation for A & E PLASTIK PAK INC (CUSIP: 000032102)
# Saved interpolation quality analysis plot to 'interpolation_quality_analysis.png'
#
# === Comparing Original vs Interpolated Data Distributions ===
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
